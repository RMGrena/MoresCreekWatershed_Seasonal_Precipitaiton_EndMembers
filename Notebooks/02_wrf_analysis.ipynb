# %% [markdown]
# ## WRF Analysis
# ### Created by Stanley Akor; Edited by Rachel Grena

# %%
import xarray as xr
import numpy as np
import pandas as pd

# %% [markdown]
# ## Helper Functions

# %%
'''
Converts latitude and longitude coordinates to WRF x and y indices.

Each 1km grid in a typical WRF output file is represented by an x and y index. 
To compare observation values in lat/lon to a WRF output, we first convert the lat/lon to WRF indices (i.e., x, y).

Parameters: 
    geog - File containing latitude and longitude coordinates in a typical WRF output file at 1km resolution.
    lat - Latitude of a site to be converted to the WRF x index.
    lon - Longitude of a site to be converted to the WRF y index.

Returns:
    ixlat - The x index of the site.
    iylon - The y index of the site.
'''

def get_wrf_xy(geog, lat, lon):
    # Example usage: lat = 38.89, lon = -106.95
    xlat = geog.XLAT.values[0, :, :]
    xlon = geog.XLONG.values[0, :, :]
    dist = np.sqrt((xlat - lat)**2 + (xlon - lon)**2)
    mindist = dist.min()
    ixlat = np.argwhere(dist == mindist)[0][0]
    iylon = np.argwhere(dist == mindist)[0][1]
    return ixlat, iylon

# %% [markdown]
# ## Import File

# %%
wrf_file = xr.open_dataset("WY_2023_wrf.nc") # , engine="netcdf4")
# Out:
# C:\Users\grena\anaconda3\envs\Mores_Creek\Lib\site-packages\xarray\backends\api.py:668: RuntimeWarning: 'scipy' fails while guessing
#   engine = plugins.guess_engine(filename_or_obj)

# %%
'''
    The wrf_file contains 9 variables on an hourly time step for the 2023 water year. Of particular interest are:
    
        T2: Temperature at 2-metres (Celsitus)
        SNOW: Snow water equivalent (mm)
        PRCP: Deaccumulated precipitation (daily precipitation (rain) in mm)
        SNOWH: Snow height (m)
        ACPRCP: Accumulated precipitation from start of the water year (mm)

'''
wrf_file

# %%
def get_wrf_data(file,lat,lon,variable):

    # open the wrf output file and extract the variable
    wrf_file = xr.open_dataset(file)

    # get wrf x/y indices for the site
    ixlat, iylon = get_wrf_xy(wrf_file, lat, lon)

    # collect data from the site

    site = wrf_file[variable].isel(south_north = ixlat, west_east = iylon)

    # create a dataframe for the site
    time =  site['XTIME'].values

    
    data = pd.DataFrame({'timestamp': time,
                         variable: site})

    # Convert the 'timestamp' column to datetime format
    data['timestamp'] = pd.to_datetime(data['timestamp'])

    # Set 'timestamp' column as the index
    data.set_index('timestamp', inplace=True)

    return data

# %% [markdown]
# <span style="color: red;">Code Cells are kept raw to save time when generating results for specific variables.</span>

# %% [markdown]
# ## Temperature

# %% [raw]
# #Temp
# # Enter lat / long of specific site
# lat = 43.6479
# lon = -115.99
#
# variable = 'T2'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
#
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# df = get_wrf_data(path_to_wrf_file,lat,lon,variable)
#
# # Resample from hourly to daily and aggregate using the mean
# df_resampled2 = df.resample('W').mean()
#
# # Convert the temperature from Kelvin to Celsius
# df_resampled2[variable] = df_resampled2[variable] - 272.15
#
# # Convert into a new DataFrame
# T_RC_1 = pd.DataFrame(df_resampled2)

# %% [raw]
# # Total Precip volume for all Sites
# variable = 'T2'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# #define rc_variables
# rc_variables = {
#     'RC_01': {'lat': 43.64792811, 'lon': -115.9897596},
#     'RC_02': {'lat': 43.74783308, 'lon': -115.8804603},
#     'RC_03': {'lat': 43.7511991, 'lon': -115.9428652},
#     'RC_04': {'lat': 43.79962177, 'lon': -115.7885124},
#     'RC_05': {'lat': 43.90746942, 'lon': -115.6930072},
#     'RC_06': {'lat': 43.92414139, 'lon': -115.6825098},
#     'RC_07': {'lat': 43.9319943, 'lon': -115.66589},
#     'RC_08': {'lat': 43.93639134, 'lon': -115.679588},
#     'RC_09': {'lat': 43.94413863, 'lon': -115.6832378},
#     'RC_10': {'lat': 43.95814402, 'lon': -115.6924836}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for rc, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Resample from hourly to daily and aggregate using the mean
#     df_temp = df.resample('W').mean()
#
#     # Convert the temperature from Kelvin to Celsius
#     df_temp[variable] = df_temp[variable] - 272.15
#
# # Print the results
# for rc, mean in results.items():
#     print(f"{rc} : mean")

# %% [raw]
# variable = 'T2'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_01': {'lat': 43.64792811, 'lon': -115.9897596},
#     'RC_02': {'lat': 43.74783308, 'lon': -115.8804603},
#     'RC_03': {'lat': 43.7511991, 'lon': -115.9428652},
#     'RC_04': {'lat': 43.79962177, 'lon': -115.7885124},
#     'RC_05': {'lat': 43.90746942, 'lon': -115.6930072},
#     'RC_06': {'lat': 43.92414139, 'lon': -115.6825098},
#     'RC_07': {'lat': 43.9319943, 'lon': -115.66589},
#     'RC_08': {'lat': 43.93639134, 'lon': -115.679588},
#     'RC_09': {'lat': 43.94413863, 'lon': -115.6832378},
#     'RC_10': {'lat': 43.95814402, 'lon': -115.6924836},
#     'IB_05': {'lat': 43.91974, 'lon': -115.686},
#     'IB_06': {'lat': 43.92639, 'lon': -115.68},
#     'IB_08': {'lat': 43.93824, 'lon': -115.682}
# }
#
# results = {}
#
# for rc, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#     df_temp = df.resample('D').mean()
#     df_temp[variable] = df_temp[variable] - 272.15
#
#     # Store the DataFrame in the results dictionary
#     results[rc] = df_temp
#
# # Concatenate all the DataFrames along the columns axis
# df_daily_temp = pd.concat(results, axis=1)
#
# # Print the final DataFrame
# df_daily_temp

# %% [raw]
# variable = 'T2'
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_01': {'lat': 43.64792811, 'lon': -115.9897596},
#     'RC_02': {'lat': 43.74783308, 'lon': -115.8804603},
#     'RC_03': {'lat': 43.7511991, 'lon': -115.9428652},
#     'RC_04': {'lat': 43.79962177, 'lon': -115.7885124},
#     'RC_05': {'lat': 43.90746942, 'lon': -115.6930072},
#     'RC_06': {'lat': 43.92414139, 'lon': -115.6825098},
#     'RC_07': {'lat': 43.9319943, 'lon': -115.66589},
#     'RC_08': {'lat': 43.93639134, 'lon': -115.679588},
#     'RC_09': {'lat': 43.94413863, 'lon': -115.6832378},
#     'RC_10': {'lat': 43.95814402, 'lon': -115.6924836},
#     'IB_05': {'lat': 43.91974, 'lon': -115.686},
#     'IB_06': {'lat': 43.92639, 'lon': -115.68},
#     'IB_08': {'lat': 43.93824, 'lon': -115.682}
# }
# results = {}
#
# for rc, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#     df_temp = df.resample('D').mean()
#     df_temp[variable] = df_temp[variable] - 272.15
#
#     # Compute the moving average with a window size of N
#     N = 7  # change this to desired window size
#     df_temp[variable] = df_temp[variable].rolling(window=N).mean()
#
#     # Store the DataFrame in the results dictionary
#     results[rc] = df_temp
#
# # Concatenate all the DataFrames along the columns axis
# df_final = pd.concat(results, axis=1)

# %% [markdown]
# ## Save results to CSV

# %% [raw]
# # Convert into a new DataFrame
# Temp = pd.DataFrame(df_final)
#
# # Or save it into a CSV file
# #Temp.to_csv('df_weekly_temp.csv')

# %% [markdown]
# ## Temparture Alternative Method Analysis: Defining Fixed Window and Moving Average Controls

# %% [raw]
# # Define a function that converts values above zero to 1 and values below zero to 0
# # Tempearture distinction for moving average and fixed window stats
# def convert_values(val):
#     if val > 0:
#         return 1
#     elif val < 0:
#         return 0
#     else:
#         return val
#
# # Apply the function to each element of the DataFrame
# df_windowavg = df_final.applymap(convert_values)

# %% [raw]
# df_windowavg.columns = df_windowavg.columns.droplevel(1)
# df_windowavg

# %% [raw]
# columns = ['RC_04']  # replace with column names
#
# for col in columns:
#     # Find the date of the first zero
#     first_zero_date = df_windowavg[df_windowavg[col] == 0].index.min()
#     print(f"The first zero in {col} is on date: {first_zero_date}")
#
#     # Find the date of the last zero
#     last_zero_date = df_windowavg[df_windowavg[col] == 0].index.max()
#     print(f"The last zero in {col} is on date: {last_zero_date}")

# %% [markdown]
# ## SNOW

# %% [raw]
# lat = 43.64793
# lon = -115.99
#
# variable = 'SNOW'  # For snow height, change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
#
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# df = get_wrf_data(path_to_wrf_file,lat,lon,variable)

# %% [raw]
# # Resample from hourly to daily and aggregate using the mean
# df_resampled = df.resample('D').mean()
#
# df_resampled.head(5)
#
# # check snow height for specific time range and convert snow height to milli-meters (multiply by 1000)
# # NOTE that only snow height is measured in meters, all others are in mm
#
# start_date = '2023-01-01'
# end_date = '2023-01-20'
# df_selected_range = df_resampled[(df_resampled.index >= start_date) & (df_resampled.index <= end_date)] * 1e3
#
# # Print the resulting DataFrame
# print(df_selected_range)

# %% [raw]
# #Site 07
# lat = 43.932
# lon = -115.666
#
# variable = 'SNOW'
#
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# seven_T = get_wrf_data(path_to_wrf_file,lat,lon,variable)
# #seven_T.to_csv('swe_7_wrf.csv')

# %% [markdown]
# ## Precipiation

# %% [raw]
# #PRCP
# lat = 43.95814402
# lon = -115.6924836
#
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
#
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# df = get_wrf_data(path_to_wrf_file,lat,lon,variable)
#
# # Resample from hourly to daily and aggregate using the mean
# df_precip = df.resample('D').sum()
# df_precip

# %%
# Total Precip volume for all Sites
variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
path_to_wrf_file = "WY_2023_wrf.nc"

#define rc_variables
rc_variables = {
    'RC_01': {'lat': 43.64792811, 'lon': -115.9897596},
    'RC_02': {'lat': 43.74783308, 'lon': -115.8804603},
    'RC_03': {'lat': 43.7511991, 'lon': -115.9428652},
    'RC_04': {'lat': 43.79962177, 'lon': -115.7885124},
    'RC_05': {'lat': 43.90746942, 'lon': -115.6930072},
    'RC_06': {'lat': 43.92414139, 'lon': -115.6825098},
    'RC_07': {'lat': 43.9319943, 'lon': -115.66589},
    'RC_08': {'lat': 43.93639134, 'lon': -115.679588},
    'RC_09': {'lat': 43.94413863, 'lon': -115.6832378},
    'RC_10': {'lat': 43.95814402, 'lon': -115.6924836}
}

# Create an empty dictionary to store the results
results = {}

# Loop over each item in rc_variables
for rc, coords in rc_variables.items():
    lat = coords['lat']
    lon = coords['lon']
    
    # Get the data
    df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
    
    # Resample from hourly to daily and aggregate using the sum
    df_precip = df.resample('D').sum()
    
    # Calculate the total sum and store it in the dictionary
    results[rc] = df_precip.sum()

# Print the results
for rc, total in results.items():
    print(f"{rc}: {total}")

# %% [markdown]
# ### Cold and Warm Season Sums for Sinusoidal Curves

# %% [raw]
# This represents Warm Season
# #I did no round the dates
# Obtained Dates 05/13/2023
# Site_no 1.0: Crossing Point at x=128.49, y=-13.40 on 2023-05-08
# Site_no 1.0: Crossing Point at x=302.05, y=-13.34 on 2023-10-29
# Site_no 2.0: Crossing Point at x=136.57, y=-13.64 on 2023-05-16
# Site_no 2.0: Crossing Point at x=301.00, y=-13.61 on 2023-10-28
# Site_no 3.0: Crossing Point at x=139.34, y=-13.95 on 2023-05-19
# Site_no 3.0: Crossing Point at x=304.35, y=-13.91 on 2023-10-31
# Site_no 4.0: Crossing Point at x=149.56, y=-14.17 on 2023-05-29
# Site_no 4.0: Crossing Point at x=299.15, y=-14.12 on 2023-10-26
# Site_no 5.0: Crossing Point at x=137.59, y=-14.92 on 2023-05-17
# Site_no 5.0: Crossing Point at x=298.75, y=-14.87 on 2023-10-25
# Site_no 6.0: Crossing Point at x=131.63, y=-14.74 on 2023-05-11
# Site_no 6.0: Crossing Point at x=303.30, y=-14.70 on 2023-10-30
# Site_no 7.0: Crossing Point at x=136.64, y=-15.15 on 2023-05-16
# Site_no 7.0: Crossing Point at x=293.99, y=-15.10 on 2023-10-21 #rounded this date
# Site_no 8.0: Crossing Point at x=133.75, y=-15.43 on 2023-05-13
# Site_no 8.0: Crossing Point at x=306.46, y=-15.39 on 2023-11-02
# Site_no 9.0: Crossing Point at x=144.05, y=-15.77 on 2023-05-24
# Site_no 9.0: Crossing Point at x=309.20, y=-15.75 on 2023-11-05
# Site_no 10: Crossing Point at x=152.20, y=-16.17 on 2023-06-01
# Site_no 10: Crossing Point at x=319.22, y=-16.14 on 2023-11-15

# %% [raw]
# # Total Precip volume for all Sites
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# #define rc_variables
# rc_variables = {
#     'RC_01': {'lat': 43.64792811, 'lon': -115.9897596},
#     'RC_02': {'lat': 43.74783308, 'lon': -115.8804603},
#     'RC_03': {'lat': 43.7511991, 'lon': -115.9428652},
#     'RC_04': {'lat': 43.79962177, 'lon': -115.7885124},
#     'RC_05': {'lat': 43.90746942, 'lon': -115.6930072},
#     'RC_06': {'lat': 43.92414139, 'lon': -115.6825098},
#     'RC_07': {'lat': 43.9319943, 'lon': -115.66589},
#     'RC_08': {'lat': 43.93639134, 'lon': -115.679588},
#     'RC_09': {'lat': 43.94413863, 'lon': -115.6832378},
#     'RC_10': {'lat': 43.95814402, 'lon': -115.6924836}
# }
#
# #Create an empty DataFrame to store the results
# df_results = pd.DataFrame()
#
# # Loop over each item in rc_variables
# for rc, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Resample from hourly to daily and aggregate using the sum
#     df_precip = df.resample('D').mean()
#     df_results[rc] = df_precip
#     # Calculate the 7-day rolling average
#     #df_precip_rolling = df_precip.rolling(window=7).mean()
#
#     # Add the rolling average data to the results DataFrame
#     #df_results[rc] = df_precip_rolling
#
# # Print the results
# #print(df_results)
#
# #df_results.to_csv('site_Precip_daily.csv')

# %%
variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
path_to_wrf_file = "WY_2023_wrf.nc"
#Site_no 10: Crossing Point at x=152.20, y=-16.17 on 2023-06-01
#Site_no 10: Crossing Point at x=319.22, y=-16.14 on 2023-11-15
rc_variables = {
     'RC_10': {'lat': 43.95814402, 'lon': -115.6924836}
}

# Create an empty dictionary to store the results
results = {}

# Loop over each item in rc_variables
for rc1, coords in rc_variables.items():
    lat = coords['lat']
    lon = coords['lon']
    
    # Get the data
    df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
    
    # Calculate the sum for each date range and store it in the dictionary
    results[rc1] = {
        '2022-10-05 to 2022-11-14': df['2022-10-05' : '2022-11-14'].sum(), # summer
        '2023-06-01 to 2023-11-03': df['2023-06-01' : '2023-11-03' ].sum(), # summer
        '2022-11-15 to 2023-05-31': df['2022-11-15' : '2023-05-31'].sum() #winter
    }

# Print the results
for rc1, sums in results.items():
    print(f"{rc1}: {sums}")

# %% [raw]
# # Precipitation Accumulation for warm (w) and cold (c) season at each site (1 through 10)
# w1 = 271.23
# c1 = 231.4
# one_totalP = 502.64
#
# w2 = 342.5
# c2 = 246.84
# two_totalP = 589.34
#
# w3 = 288.96
# c3 = 234.26
# three_totalP = 523.22
#
# w4 = 397.77
# c4 = 246.54
# four_totalP = 644.31
#
# w5 = 541.59
# c5 = 383.68
# five_totalP = 925.27
#
# w6 = 611
# c6 = 422.69
# six_totalP = 1033.69
#
# w7 = 637.25
# c7 = 451.58
# seven_totalP = 1088.83
#
# w8 = 645.77
# c8 = 473.12
# eight_totalP = 1118.89
#
# w9 = 702.11
# c9 = 495.58
# nine_totalP = 1197.69
#
# w10 = 806.4
# c10 = 522.92
# ten_totalP = 1329.32

# %% [markdown]
# #### Precipitation Accumulation: Moving Average (7 day) per site
# Each cell represents each rain collector (RC) and interval board (IB) site.

# %% [raw]
# # Total Precip volume for all Sites
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# #define rc_variables
# rc_variables = {
#     'RC_01': {'lat': 43.64792811, 'lon': -115.9897596},
#     'RC_02': {'lat': 43.74783308, 'lon': -115.8804603},
#     'RC_03': {'lat': 43.7511991, 'lon': -115.9428652},
#     'RC_04': {'lat': 43.79962177, 'lon': -115.7885124},
#     'RC_05': {'lat': 43.90746942, 'lon': -115.6930072},
#     'RC_06': {'lat': 43.92414139, 'lon': -115.6825098},
#     'RC_07': {'lat': 43.9319943, 'lon': -115.66589},
#     'RC_08': {'lat': 43.93639134, 'lon': -115.679588},
#     'RC_09': {'lat': 43.94413863, 'lon': -115.6832378},
#     'RC_10': {'lat': 43.95814402, 'lon': -115.6924836}
# }
#
# #Create an empty DataFrame to store the results
# df_results = pd.DataFrame()
#
# # Loop over each item in rc_variables
# for rc, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Resample from hourly to daily and aggregate using the sum
#     df_precip = df.resample('D').mean()
#     df_results[rc] = df_precip
#     # Calculate the 7-day rolling average
#     #df_precip_rolling = df_precip.rolling(window=7).mean()
#
#     # Add the rolling average data to the results DataFrame
#     #df_results[rc] = df_precip_rolling
#
# # Print the results
# #print(df_results)
#
# #df_results.to_csv('site_Precip_daily.csv')

# %% [raw]
# # rc_variables need to be changed for each site and specified dates
# #RC_01
#
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_01': {'lat': 43.64792811, 'lon': -115.9897596}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for rc1, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[rc1] = {
#         '2022-10-05 to 2022-10-27': df['2022-10-05' : '2022-10-27'].sum(),
#         '2022-10-28 to 2022-11-13': df['2022-10-28' : '2022-11-13'].sum(),
#         '2023-03-02 to 2023-03-16': df['2023-03-02' : '2023-03-16'].sum(),
#         '2023-03-17 to 2023-06-29': df['2023-03-17' : '2023-06-29'].sum(),
#         '2023-06-30 to 2023-08-08': df['2023-06-30' : '2023-08-08'].sum(),
#         '2023-08-09 to 2023-08-26': df['2023-08-09' : '2023-08-26'].sum(),
#         '2023-08-27 to 2023-09-07': df['2023-08-27' : '2023-09-07'].sum(),
#         '2023-09-08 to 2023-10-12': df['2023-09-08' : '2023-10-12'].sum()
#     }
#
# # Print the results
# for rc1, sums in results.items():
#     print(f"{rc1}: {sums}")

# %% [raw]
# #IB_01
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'IB_01': {'lat': 43.64792811, 'lon': -115.9897596}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for ib1, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[ib1] = {
#         '2022-11-14 to 2022-12-03': df['2022-11-14' : '2022-12-03'].sum(),
#         '2022-12-04 to 2022-12-19': df['2022-12-04' : '2022-12-19'].sum(),
#         '2022-12-20 to 2023-01-02': df['2022-12-20' : '2023-01-02'].sum(),
#         '2023-01-03 to 2023-02-01': df['2023-01-03' : '2023-02-01'].sum(),
#         '2023-02-02 to 2023-02-15': df['2023-02-02' : '2023-02-15'].sum(),
#         '2023-02-16 to 2023-03-01': df['2023-02-16' : '2023-03-01'].sum()
#     }
#
# # Print the results
# for ib1, sums in results.items():
#     print(f"{ib1}: {sums}")

# %% [raw]
# #RC_02
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_02': {'lat': 43.74783308, 'lon': -115.8804603}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for rc2, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[rc2] = {
#         '2022-10-05 to 2022-10-27': df['2022-10-05' : '2022-10-27'].sum(),
#         '2022-10-28 to 2022-11-13': df['2022-10-28' : '2022-11-13'].sum(),
#         '2023-03-17 to 2023-05-16': df['2023-03-17' : '2023-05-16'].sum(),
#         '2023-05-17 to 2023-05-31': df['2023-05-17' : '2023-05-31'].sum(),
#         '2023-06-01 to 2023-06-11': df['2023-06-01' : '2023-06-11'].sum(),
#         '2023-06-12 to 2023-06-29': df['2023-06-12' : '2023-06-29'].sum(),
#         '2023-06-30 to 2023-08-08': df['2023-06-30' : '2023-08-08'].sum(),
#         '2023-08-09 to 2023-08-26': df['2023-08-09' : '2023-08-26'].sum(),
#         '2023-08-27 to 2023-09-07': df['2023-08-27' : '2023-09-07'].sum(),
#         '2023-09-08 to 2023-09-28': df['2023-09-08' : '2023-09-28'].sum(),
#         '2023-09-29 to 2023-10-12': df['2023-09-29' : '2023-10-12'].sum()
#     }
#
# # Print the results
# for rc2, sums in results.items():
#     print(f"{rc2}: {sums}")

# %% [raw]
# #IB_02
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'IB_02': {'lat': 43.74783308, 'lon': -115.8804603}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for ib2, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[ib2] = {
#         '2022-11-14 to 2022-12-03': df['2022-11-14' : '2022-12-03'].sum(),
#         '2022-12-04 to 2022-12-19': df['2022-12-04' : '2022-12-19'].sum(),
#         '2022-12-20 to 2023-01-02': df['2022-12-20' : '2023-01-02'].sum(),
#         '2023-01-03 to 2023-02-01': df['2023-01-03' : '2023-02-01'].sum(),
#         '2023-02-02 to 2023-02-15': df['2023-02-02' : '2023-02-15'].sum(),
#         '2023-02-16 to 2023-03-01': df['2023-02-16' : '2023-03-01'].sum(),
#         '2023-03-02 to 2023-03-16': df['2023-03-02' : '2023-03-16'].sum()
#     }
#
# # Print the results
# for ib2, sums in results.items():
#     print(f"{ib2}: {sums}")

# %% [raw]
# #RC_03
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_03': {'lat': 43.7511991, 'lon': -115.9428652}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for rc3, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[rc3] = {
#         '2022-10-05 to 2022-10-27': df['2022-10-05' : '2022-10-27'].sum(),
#         '2022-10-28 to 2022-12-03': df['2022-10-28' : '2022-12-03'].sum(),
#         '2023-03-17 to 2023-05-16': df['2023-03-17' : '2023-05-16'].sum(),
#         '2023-05-17 to 2023-06-29': df['2023-05-17' : '2023-06-29'].sum(),
#         '2023-06-30 to 2023-08-08': df['2023-06-30' : '2023-08-08'].sum(),
#         '2023-08-09 to 2023-08-26': df['2023-08-09' : '2023-08-26'].sum(),
#         '2023-08-27 to 2023-09-07': df['2023-08-27' : '2023-09-07'].sum(),
#         '2023-09-08 to 2023-09-28': df['2023-09-08' : '2023-09-28'].sum(),
#         '2023-09-29 to 2023-10-12': df['2023-09-29' : '2023-10-12'].sum()
#     }
#
# # Print the results
# for rc3, sums in results.items():
#     print(f"{rc3}: {sums}")

# %% [raw]
# #IB_03
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'IB_03': {'lat': 43.74668, 'lon': -115.944}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for ib3, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[ib3] = {
#         '2022-12-04 to 2022-12-18': df['2022-12-04' : '2022-12-18'].sum(),
#         '2022-12-19 to 2023-01-02': df['2022-12-19' : '2023-01-02'].sum(),
#         '2023-01-03 to 2023-02-01': df['2023-01-03' : '2023-02-01'].sum(),
#         '2023-02-02 to 2023-02-15': df['2023-02-02' : '2023-02-15'].sum(),
#         '2023-02-16 to 2023-03-01': df['2023-02-16' : '2023-03-01'].sum(),
#         '2023-03-02 to 2023-03-05': df['2023-03-02' : '2023-03-05'].sum(),
#         '2023-03-06 to 2023-03-16': df['2023-03-06' : '2023-03-16'].sum()
#     }
#
# # Print the results
# for ib3, sums in results.items():
#     print(f"{ib3}: {sums}")

# %% [raw]
# #IB_04
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_04': {'lat': 43.79962177, 'lon': -115.7885124}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for rc4, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[rc4] = {
#         '2022-10-05 to 2022-10-27': df['2022-10-05' : '2022-10-27'].sum(),
#         '2022-10-28 to 2022-12-06': df['2022-10-28' : '2022-12-06'].sum(),
#         '2022-12-07 to 2022-12-18': df['2022-12-07' : '2022-12-18'].sum(),
#         '2023-04-06 to 2023-05-16': df['2023-04-06' : '2023-05-16'].sum(),
#         '2023-05-17 to 2023-05-31': df['2023-05-17' : '2023-05-31'].sum(),
#         '2023-06-01 to 2023-06-11': df['2023-06-01' : '2023-06-11'].sum(),
#         '2023-06-12 to 2023-06-29': df['2023-06-12' : '2023-06-29'].sum(),
#         '2023-06-30 to 2023-08-08': df['2023-06-30' : '2023-08-08'].sum(),
#         '2023-08-09 to 2023-08-26': df['2023-08-09' : '2023-08-26'].sum(),
#         '2023-08-27 to 2023-09-07': df['2023-08-27' : '2023-09-07'].sum(),
#         '2023-09-08 to 2023-09-28': df['2023-09-08' : '2023-09-28'].sum(),
#         '2023-09-29 to 2023-10-12': df['2023-09-29' : '2023-10-12'].sum()
#     }
#
# # Print the results
# for rc4, sums in results.items():
#     print(f"{rc4}: {sums}")

# %% [raw]
# #IB_04
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'IB_04': {'lat': 43.79962177, 'lon': -115.7885124}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for ib4, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[ib4] = {
#         '2022-12-07 to 2022-12-18': df['2022-12-07' : '2022-12-18'].sum(),
#         '2022-12-19 to 2023-02-01': df['2022-12-19' : '2023-02-01'].sum(),
#         '2023-02-02 to 2023-02-15': df['2023-02-02' : '2023-02-15'].sum(),
#         '2023-02-16 to 2023-03-01': df['2023-02-16' : '2023-03-01'].sum(),
#         '2023-03-02 to 2023-03-16': df['2023-03-02' : '2023-03-16'].sum(),
#         '2023-03-17 to 2023-04-05': df['2023-03-17' : '2023-04-05'].sum()
#     }
#
# # Print the results
# for ib4, sums in results.items():
#     print(f"{ib4}: {sums}")

# %% [raw]
# #RC_05
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_05': {'lat': 43.90746942, 'lon': -115.6930072}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for rc5, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[rc5] = {
#         '2022-10-05 to 2022-10-27': df['2022-10-05' : '2022-10-27'].sum(),
#         '2023-04-06 to 2023-06-11': df['2023-04-06' : '2023-06-11'].sum(),
#         '2023-06-12 to 2023-06-29': df['2023-06-12' : '2023-06-29'].sum(),
#         '2023-06-30 to 2023-08-08': df['2023-06-30' : '2023-08-08'].sum(),
#         '2023-08-09 to 2023-08-26': df['2023-08-09' : '2023-08-26'].sum(),
#         '2023-08-27 to 2023-09-07': df['2023-08-27' : '2023-09-07'].sum(),
#         '2023-09-08 to 2023-09-28': df['2023-09-08' : '2023-09-28'].sum(),
#         '2023-09-29 to 2023-10-12': df['2023-09-29' : '2023-10-12'].sum()
#     }
#
# # Print the results
# for rc5, sums in results.items():
#     print(f"{rc5}: {sums}")

# %% [raw]
# #IB_05
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'IB_05': {'lat': 43.91974, 'lon': -115.686}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for ib5, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[ib5] = {
#         '2022-10-28 to 2022-12-18': df['2022-10-28' : '2022-12-18'].sum(),
#         '2022-12-19 to 2023-01-02': df['2022-12-19' : '2023-01-02'].sum(),
#         '2023-01-03 to 2023-01-11': df['2023-01-03' : '2023-01-11'].sum(),
#         '2023-01-12 to 2023-01-18': df['2023-01-12' : '2023-01-18'].sum(),
#         '2023-01-19 to 2023-02-01': df['2023-01-19' : '2023-02-01'].sum(),
#         '2023-02-02 to 2023-02-15': df['2023-02-02' : '2023-02-15'].sum(),
#         '2023-02-16 to 2023-03-09': df['2023-01-16' : '2023-03-09'].sum(),
#         '2023-03-10 to 2023-03-16': df['2023-03-10' : '2023-03-16'].sum(),
#         '2023-03-17 to 2023-04-05': df['2023-03-17' : '2023-04-05'].sum()
#     }
#
# # Print the results
# for ib5, sums in results.items():
#     print(f"{ib5}: {sums}")

# %% [raw]
# #RC_06
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_06': {'lat': 43.92414139, 'lon': -115.6825098}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for rc6, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[rc6] = {
#         '2022-10-05 to 2022-10-27': df['2022-10-05' : '2022-10-27'].sum(),
#         '2022-10-28 to 2022-12-07': df['2022-10-28' : '2022-12-07'].sum(),
#         '2023-04-06 to 2023-05-31': df['2023-04-06' : '2023-05-31'].sum(),
#         '2023-06-01 to 2023-06-11': df['2023-06-01' : '2023-06-11'].sum(),
#         '2023-06-12 to 2023-06-29': df['2023-06-12' : '2023-06-29'].sum(),
#         '2023-06-30 to 2023-08-08': df['2023-06-30' : '2023-08-08'].sum(),
#         '2023-08-09 to 2023-08-26': df['2023-08-09' : '2023-08-26'].sum(),
#         '2023-08-27 to 2023-09-07': df['2023-08-27' : '2023-09-07'].sum(),
#         '2023-09-08 to 2023-09-28': df['2023-09-08' : '2023-09-28'].sum(),
#         '2023-09-29 to 2023-10-12': df['2023-09-29' : '2023-10-12'].sum()
#     }
#
# #print results
# for rc6, sums in results.items():
#     print(f"{rc6}: {sums}")

# %% [raw]
# #IB_06
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'IB_06': {'lat': 43.92639, 'lon': -115.68}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for ib6, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[ib6] = {
#         '2022-12-08 to 2022-12-18': df['2022-12-08' : '2022-12-18'].sum(),
#         '2022-12-19 to 2023-01-02': df['2022-12-19' : '2023-01-02'].sum(),
#         '2023-01-03 to 2023-01-11': df['2023-01-03' : '2023-01-11'].sum(),
#         '2023-01-12 to 2023-01-18': df['2023-01-12' : '2023-01-18'].sum(),
#         '2023-01-19 to 2023-02-01': df['2023-01-19' : '2023-02-01'].sum(),
#         '2023-02-02 to 2023-02-15': df['2023-02-02' : '2023-02-15'].sum(),
#         '2023-02-16 to 2023-03-09': df['2023-01-16' : '2023-03-09'].sum(),
#         '2023-03-10 to 2023-03-16': df['2023-03-10' : '2023-03-16'].sum(),
#         '2023-03-17 to 2023-04-05': df['2023-03-17' : '2023-04-05'].sum(),
#     }
#
# #print results
# for ib6, sums in results.items():
#     print(f"{ib6}: {sums}")

# %% [raw]
# #RC_07
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_07': {'lat': 43.9319943, 'lon': -115.66589}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for rc7, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[rc7] = {
#         '2022-10-05 to 2022-10-27': df['2022-10-05' : '2022-10-27'].sum(),
#         '2023-04-06 to 2023-05-31': df['2023-04-06' : '2023-05-31'].sum(),
#         '2023-06-01 to 2023-06-11': df['2023-06-01' : '2023-06-11'].sum(),
#         '2023-06-12 to 2023-06-29': df['2023-06-12' : '2023-06-29'].sum(),
#         '2023-06-30 to 2023-08-08': df['2023-06-30' : '2023-08-08'].sum(),
#         '2023-08-09 to 2023-08-26': df['2023-08-09' : '2023-08-26'].sum(),
#         '2023-08-27 to 2023-09-07': df['2023-08-27' : '2023-09-07'].sum(),
#         '2023-09-08 to 2023-09-28': df['2023-09-08' : '2023-09-29'].sum(),
#         '2023-09-29 to 2023-10-12': df['2023-09-29' : '2023-10-12'].sum()
#     }
#
# # Print the results
# for rc7, sums in results.items():
#     print(f"{rc7}: {sums}")

# %% [raw]
# #IB_07
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'IB_07': {'lat': 43.9319943, 'lon': -115.66589}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for ib7, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[ib7] = {
#         '2022-10-28 to 2022-12-14': df['2022-10-28' : '2022-12-14'].sum(),
#         '2022-12-15 to 2022-12-18': df['2022-12-15' : '2022-12-18'].sum(),
#         '2022-12-19 to 2023-01-05': df['2022-12-19' : '2023-01-05'].sum(),
#         '2023-01-06 to 2023-01-11': df['2023-01-06' : '2023-01-11'].sum(),
#         '2023-01-12 to 2023-01-18': df['2023-01-12' : '2023-01-18'].sum(),
#         '2023-01-19 to 2023-02-01': df['2023-01-19' : '2023-02-01'].sum(),
#         '2023-02-02 to 2023-02-15': df['2023-02-02' : '2023-02-15'].sum(),
#         '2023-02-16 to 2023-03-09': df['2023-01-16' : '2023-03-09'].sum(),
#         '2023-03-10 to 2023-03-16': df['2023-03-10' : '2023-03-16'].sum(),
#         '2023-03-17 to 2023-04-05': df['2023-03-17' : '2023-04-05'].sum()
#     }
#
# # Print the results
# for ib7, sums in results.items():
#     print(f"{ib7}: {sums}")

# %% [raw]
# #RC_08
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_08': {'lat': 43.93639134, 'lon': -115.679588}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for rc8, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[rc8] = {
#         '2022-10-05 to 2022-11-11': df['2022-10-05' : '2022-11-11'].sum(),
#         '2023-03-19 to 2023-06-29': df['2023-03-19' : '2023-06-29'].sum(),
#         '2023-06-30 to 2023-08-26': df['2023-06-30' : '2023-08-26'].sum(),
#         '2023-08-27 to 2023-11-03': df['2023-08-27' : '2023-11-03'].sum()
#     }
#
# # Print the results
# for rc8, sums in results.items():
#     print(f"{rc8}: {sums}")

# %% [raw]
# #IB_08
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'IB_08': {'lat': 43.93824, 'lon': -115.682}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for ib8, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[ib8] = {
#         '2022-11-12 to 2022-12-09': df['2022-11-12' : '2022-12-09'].sum(),
#         '2022-12-10 to 2022-12-14': df['2022-12-10' : '2022-12-14'].sum(),
#         '2022-12-15 to 2023-01-05': df['2022-12-15' : '2023-01-05'].sum(),
#         '2023-01-06 to 2023-01-11': df['2023-01-06' : '2023-01-11'].sum(),
#         '2023-01-12 to 2023-02-01': df['2023-01-12' : '2023-02-01'].sum(),
#         '2023-02-02 to 2023-03-09': df['2023-02-02' : '2023-03-09'].sum(),
#         '2023-03-10 to 2023-03-18': df['2023-03-10' : '2023-03-18'].sum()
#     }
#
# # Print the results
# for ib8, sums in results.items():
#     print(f"{ib8}: {sums}")

# %% [raw]
# #RC_09
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_09': {'lat': 43.94413863, 'lon': -115.6832378}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for rc9, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[rc9] = {
#         '2022-10-05 to 2022-11-11': df['2022-10-05' : '2022-11-11'].sum(),
#         '2023-04-06 to 2023-06-29': df['2023-04-06' : '2023-06-29'].sum(),
#         '2023-06-30 to 2023-08-26': df['2023-06-30' : '2023-08-26'].sum(),
#         '2023-08-27 to 2023-11-03': df['2023-08-27' : '2023-11-03'].sum()
#     }
#
# # Print the results
# for rc9, sums in results.items():
#     print(f"{rc9}: {sums}")

# %% [raw]
# #IB_09
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'IB_09': {'lat': 43.94415, 'lon': -115.684}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for ib9, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[ib9] = {
#         '2022-11-12 to 2022-12-09': df['2022-11-12' : '2022-12-09'].sum(),
#         '2022-12-10 to 2022-12-14': df['2022-12-10' : '2022-12-14'].sum(),
#         '2022-12-15 to 2023-01-05': df['2022-12-15' : '2023-01-05'].sum(),
#         '2023-01-06 to 2023-01-11': df['2023-01-06' : '2023-01-11'].sum(),
#         '2023-01-12 to 2023-02-01': df['2023-01-12' : '2023-02-01'].sum(),
#         '2023-02-02 to 2023-03-09': df['2023-02-02' : '2023-03-09'].sum(),
#         '2023-03-10 to 2023-03-18': df['2023-03-10' : '2023-03-18'].sum(),
#         '2023-03-19 to 2023-04-05': df['2023-03-19' : '2023-04-05'].sum()
#     }
#
# # Print the results
# for ib9, sums in results.items():
#     print(f"{ib9}: {sums}")

# %% [raw]
# #IB_10
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'IB_10': {'lat': 43.95814402, 'lon': -115.6924836}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for ib10, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[ib10] = {
#         '2022-11-12 to 2022-12-09': df['2022-11-12' : '2022-12-09'].sum(),
#         '2022-12-10 to 2022-12-14': df['2022-12-10' : '2022-12-14'].sum(),
#         '2022-12-15 to 2023-02-01': df['2022-12-15' : '2023-02-01'].sum(),
#         '2023-02-02 to 2023-03-09': df['2023-02-02' : '2023-03-09'].sum(),
#         '2023-03-10 to 2023-03-18': df['2023-03-10' : '2023-03-18'].sum(),
#         '2023-03-19 to 2023-04-05': df['2023-03-19' : '2023-04-05'].sum()
#     }
#
# # Print the results
# for ib10, sums in results.items():
#     print(f"{ib10}: {sums}")

# %% [raw]
# #RC_10
# variable = 'PRCP'  # change as need: ("PRCP", 'ACPRCP', 'T2', 'SNOW')
# path_to_wrf_file = "WY_2023_wrf.nc"
#
# rc_variables = {
#     'RC_10': {'lat': 43.95814402, 'lon': -115.6924836}
# }
#
# # Create an empty dictionary to store the results
# results = {}
#
# # Loop over each item in rc_variables
# for rc10, coords in rc_variables.items():
#     lat = coords['lat']
#     lon = coords['lon']
#
#     # Get the data
#     df = get_wrf_data(path_to_wrf_file, lat, lon, variable)
#
#     # Calculate the sum for each date range and store it in the dictionary
#     results[rc10] = {
#         '2022-10-05 to 2022-11-11': df['2022-10-05' : '2022-11-11'].sum(),
#         '2023-04-06 to 2023-06-29': df['2023-04-06' : '2023-06-29'].sum(),
#         '2023-06-30 to 2023-08-26': df['2023-06-30' : '2023-08-26'].sum(),
#         '2023-08-27 to 2023-11-03': df['2023-08-27' : '2023-11-03'].sum()
#     }
#
# # Print the results
# for rc10, sums in results.items():
#     print(f"{rc10}: {sums}")
